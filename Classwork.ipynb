# %%
import matplotlib.pyplot as plt
pop_dict = {'Category': ['Less than 18','18-60','senior citizen'], 'values':[500,800,600]}
normal_dict  = {'a':1,"b":2,"c":3}
print(normal_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
print(pop_dict)
# Out:
# {'Category': ['Less than 18', '18-60', 'senior citizen'], 'values': [500, 800, 600]}

# %%
plt.bar(pop_dict['Category'],pop_dict['values'])
# Out:
# <BarContainer object of 3 artists>
